# %%
import numpy as np
import matplotlib.pyplot as plt
from tensor_svd_denoise import scree_plots, tensor_svd_denoise
import time
import scipy.io as scio


path1 = 'E:/code/segymat/HBadd3'
data = scio.loadmat(path1)
#print(data.keys())
data_noisy1=data['VBcD1']
data_noisy2=data['VBcD2']
data_noisy3=data['VBcD3']
print(data_noisy3.shape)

d1=data['Vface1']
d2=data['Vface2']
d3=data['Vface3']
print(d3.shape)
fig = plt.figure(figsize=(6,4))
plt.subplots_adjust(left=None,bottom=None,right=None,top=None,wspace=0.001,hspace=None)


plt.subplot(131)
plt.imshow(d1)
#plt.title('4ns',fontsize = 16)
#plt.ylabel('data', fontsize = 16)
#plt.colorbar()
plt.xticks([])
plt.yticks([])

plt.subplot(132)
plt.imshow(d2)
#plt.title('4ns',fontsize = 16)
#plt.ylabel('data', fontsize = 16)
#plt.colorbar()
plt.xticks([])
plt.yticks([])

plt.subplot(133)
plt.imshow(d3)
#plt.title('4ns',fontsize = 16)
#plt.ylabel('data', fontsize = 16)
#plt.colorbar()
plt.xticks([])
plt.yticks([])

fig = plt.figure(figsize=(14,14))
plt.subplot(131)
plt.imshow(data_noisy1)
#plt.title('4ns',fontsize = 16)
#plt.ylabel('data', fontsize = 16)
#plt.colorbar()
plt.xticks([])
plt.yticks([])



plt.subplot(132)
plt.imshow(data_noisy2)
#plt.title('4ns',fontsize = 16)
#plt.ylabel('data', fontsize = 16)
#plt.colorbar()
plt.xticks([])
plt.yticks([])



plt.subplot(133)
plt.imshow(data_noisy3)
#plt.title('4ns',fontsize = 16)
#plt.ylabel('data', fontsize = 16)
#plt.colorbar()
plt.xticks([])
plt.yticks([])
# Out:
# (250, 301)
# (250, 16)
# ([], <a list of 0 Text yticklabel objects>)

# %%
import numpy as np
import matplotlib.pyplot as plt
#from tensor_svd_denoise import scree_plots, tensor_svd_denoise
import time
#import scipy.io as scio


path1 = 'E:/code/segymat/HBadd3'
data = scio.loadmat(path1)
#print(data.keys())
data_noisy1=data['HBadd1']
data_noisy2=data['HBadd2']
data_noisy3=data['HBadd3']
print(data_noisy3.shape)

fig = plt.figure(figsize=(14,14))
plt.subplots_adjust(left=None,bottom=None,right=None,top=None,wspace=0.05,hspace=None)


plt.subplot(131)
plt.imshow(data_noisy1)
plt.title('1*10',fontsize = 16)
plt.ylabel('4ns', fontsize = 16)
#plt.colorbar()
plt.xticks([])
plt.yticks([])

plt.subplot(132)
plt.imshow(data_noisy2)
plt.title('1*15',fontsize = 16)
#plt.ylabel('data', fontsize = 16)
#plt.colorbar()
plt.xticks([])
plt.yticks([])

plt.subplot(133)
plt.imshow(data_noisy3)
plt.title('1*21',fontsize = 16)
#plt.ylabel('data', fontsize = 16)
#plt.colorbar()
plt.xticks([])
plt.yticks([])
# Out:
# (301, 399)
# ([], <a list of 0 Text yticklabel objects>)
